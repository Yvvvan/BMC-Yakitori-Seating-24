# %%
# 读取csv
import csv
# 随机打乱座位
import itertools
import random
import copy
from tokenize import group


round_cnt = 5
group_cnt = 21


for seed in range(0, 1):
    for script_no in [26]: 
        seating = {}
        
        random.seed(seed)
        
        for _round in range(1, round_cnt+1): 
            for _group in range(1, group_cnt+1): 
                seating[_round, _group] = []
                
        with open('golfer_solution/golfer_solution (%d).csv'%script_no, 'r') as f:
            # 第一行是标题
            reader = csv.reader(f)
            header = next(reader)
            for row in reader:
                # 玩家
                player = int(row[0].split(' ')[1])
                
                for _round in range(1, round_cnt+1):
                    _group = int(row[_round].split(' ')[1])
                    seating[_round, _group].append(player)
                        
            # initialize player seating
            player_seating = {}
            player_seating_show = {}
            for _player in range(1, 4*group_cnt+1): 
                player_seating[_player] = [0, 0, 0, 0] # east, south, west, north
                # player_seating_show[_player] = {1:(),2:(),3:(),4:(),5:(),6:()}
                player_seating_show[_player] = {}
                for _round in range(1, round_cnt+1):
                    player_seating_show[_player][_round] = ()
                
            # initialize group seating
            seating_copy = copy.deepcopy(seating)

            for _round in range(1, round_cnt+1):
                print()
                for _group in range(1, group_cnt+1):
                    
                    p1 = seating_copy[_round, _group][0]
                    p2 = seating_copy[_round, _group][1]
                    p3 = seating_copy[_round, _group][2]
                    p4 = seating_copy[_round, _group][3]
                    p1seating = player_seating[p1] #[east,south,west,north]
                    p2seating = player_seating[p2]
                    p3seating = player_seating[p3]
                    p4seating = player_seating[p4]
                    
                    done = False
                    
                    # do a random permutation
                    temp_list = [p1, p2, p3, p4]
                    random.shuffle(temp_list)

                    for _permutation in itertools.permutations(temp_list):
                        east = _permutation[0]
                        south = _permutation[1]
                        west = _permutation[2]
                        north = _permutation[3]
                        
                        ## ① 往最少的地方坐
                        # if player_seating[east][0] is min(player_seating[east]) 
                        if player_seating[east][0] == min(player_seating[east]) and player_seating[south][1] == min(player_seating[south]) and player_seating[west][2] == min(player_seating[west]) and player_seating[north][3] == min(player_seating[north]):
                            seating_copy[_round, _group] = [east, south, west, north]
                            player_seating[east][0] += 1
                            player_seating[south][1] += 1
                            player_seating[west][2] += 1
                            player_seating[north][3] += 1
                            player_seating_show[east][_round] = (_group,'東')
                            player_seating_show[south][_round] = (_group,'南')
                            player_seating_show[west][_round] = (_group,'西')
                            player_seating_show[north][_round] = (_group,'北')
                            done = True
                            print (f'{east}-{south}-{west}-{north}')
                            break
                        
                    if not done:
                        for _permutation in itertools.permutations([p1, p2, p3, p4]):
                            east = _permutation[0]
                            south = _permutation[1]
                            west = _permutation[2]
                            north = _permutation[3]
                            
                            ## ② 往第二少的地方坐
                            # if player_seating[east][0] in sorted(player_seating[east])[:2]
                            if player_seating[east][0] in sorted(player_seating[east])[:2] and player_seating[south][1] in sorted(player_seating[south])[:2] and player_seating[west][2] in sorted(player_seating[west])[:2] and player_seating[north][3] in sorted(player_seating[north])[:2]:
                                seating_copy[_round, _group] = [east, south, west, north]
                                player_seating[east][0] += 1
                                player_seating[south][1] += 1
                                player_seating[west][2] += 1
                                player_seating[north][3] += 1
                                player_seating_show[east][_round] = (_group,'東')
                                player_seating_show[south][_round] = (_group,'南')
                                player_seating_show[west][_round] = (_group,'西')
                                player_seating_show[north][_round] = (_group,'北')
                                done = True
                                print (f'{east}-{south}-{west}-{north}')
                                break
                            
                        
                        
                        
                        else:
                            ## ③ 随机坐
                            random.shuffle(seating_copy[_round, _group])
                            player_seating[seating_copy[_round, _group][0]][0] += 1
                            player_seating[seating_copy[_round, _group][1]][1] += 1
                            player_seating[seating_copy[_round, _group][2]][2] += 1
                            player_seating[seating_copy[_round, _group][3]][3] += 1
                            player_seating_show[seating_copy[_round, _group][0]][_round] = (_group,'東')
                            player_seating_show[seating_copy[_round, _group][1]][_round] = (_group,'南')
                            player_seating_show[seating_copy[_round, _group][2]][_round] = (_group,'西')
                            player_seating_show[seating_copy[_round, _group][3]][_round] = (_group,'北')
                            east = seating_copy[_round, _group][0]
                            south = seating_copy[_round, _group][1]
                            west = seating_copy[_round, _group][2]
                            north = seating_copy[_round, _group][3]
                            print (f'{east}-{south}-{west}-{north}')
                            
            # check if all players are seated in every wind
            print ()
            print ('script %d:'%script_no)
            error = 0
            for p in player_seating:
                if 0 in player_seating[p]:
                    print (f'Player {p} does not have every wind, {player_seating[p]}')
                    error += 1
            print (seed, error)

            # if error <= 2:
            #     print ("xxxx", script_no, seed, error, "xxxx")
# Out:
# - Checking seed 0
#
# 65-18-27-78
# 42-54-66-55
# 16-77-35-80
# 25-6-69-52
# 39-9-50-20
# 60-43-49-21
# 34-4-45-28
# 67-13-44-12
# 19-7-41-68
# 10-38-14-36
# 23-76-70-30
# 37-57-75-82
# 17-63-32-11
# 73-61-72-48
# 83-26-59-2
# 51-29-15-47
# 33-64-71-24
# 8-58-1-5
# 81-74-84-22
# 46-31-3-56
# 53-40-79-62
#
# 14-12-24-50
# 55-21-7-18
# 61-35-28-84
# 75-83-31-81
# 79-80-78-9
# 22-46-82-1
# 66-36-58-4
# 63-37-62-13
# 76-34-19-72
# 2-49-74-45
# 44-73-47-54
# 71-30-68-27
# 77-39-23-17
# 41-10-6-8
# 20-65-56-16
# 29-42-33-38
# 64-15-60-70
# 11-67-51-26
# 69-59-43-32
# 5-25-53-3
# 52-48-57-40
#
# 72-52-18-66
# 40-69-67-7
# 50-33-36-31
# 12-11-47-81
# 78-35-60-6
# 41-22-29-16
# 55-45-32-68
# 3-2-76-64
# 62-8-46-15
# 49-82-26-77
# 43-1-39-34
# 57-79-20-71
# 80-5-38-51
# 27-28-83-19
# 30-14-17-37
# 58-75-10-73
# 24-23-9-44
# 54-70-21-61
# 48-56-25-59
# 74-53-42-63
# 13-84-4-65
#
# 27-37-51-66
# 10-17-42-50
# 6-68-24-54
# 47-78-5-33
# 15-45-52-84
# 22-65-75-79
# 2-36-63-82
# 39-44-55-46
# 21-41-62-67
# 4-73-83-35
# 20-26-81-72
# 8-11-57-69
# 1-23-74-80
# 19-40-43-58
# 28-30-38-48
# 7-9-16-76
# 14-31-34-53
# 49-56-61-64
# 3-32-71-77
# 18-60-12-25
# 13-29-59-70
#
# 61-34-37-41
# 68-82-84-73
# 52-55-22-49
# 45-78-17-29
# 31-72-40-39
# 56-19-44-53
# 32-66-6-67
# 11-42-70-65
# 38-24-1-60
# 25-71-26-35
# 21-14-58-83
# 9-27-36-74
# 23-10-28-47
# 46-50-2-75
# 5-20-77-76
# 7-81-8-63
# 33-13-54-69
# 48-51-64-79
# 16-3-30-59
# 4-12-15-57
# 18-62-80-43
#
# script 26:
# Player 10 does not have every wind, [2, 2, 1, 0]
# Player 11 does not have every wind, [2, 2, 0, 1]
# Player 13 does not have every wind, [2, 2, 0, 1]
# Player 14 does not have every wind, [2, 2, 1, 0]
# Player 16 does not have every wind, [2, 0, 1, 2]
# Player 23 does not have every wind, [2, 2, 1, 0]
# Player 26 does not have every wind, [0, 2, 2, 1]
# Player 35 does not have every wind, [0, 2, 1, 2]
# Player 36 does not have every wind, [0, 2, 2, 1]
# Player 42 does not have every wind, [1, 2, 2, 0]
# Player 47 does not have every wind, [1, 0, 2, 2]
# Player 48 does not have every wind, [2, 1, 0, 2]
# Player 59 does not have every wind, [0, 1, 2, 2]
# Player 65 does not have every wind, [1, 2, 0, 2]
# Player 70 does not have every wind, [0, 1, 2, 2]
# Player 73 does not have every wind, [1, 2, 0, 2]
# Player 82 does not have every wind, [0, 2, 1, 2]
# Player 84 does not have every wind, [0, 1, 2, 2]
# 0 18

# %%
# 将 player_seating_show 的 dict 转换 php的array 然后print
print ('$seats = array(')
for p in player_seating_show:
    print (f'    {p} => array(')
    for r in player_seating_show[p]:
        print (f'        {r} => array{player_seating_show[p][r]},')
    print ('    ),')
print (');')
print ()
# Out:
# $seats = array(
#     1 => array(
#         1 => array(18, '西'),
#         2 => array(6, '北'),
#         3 => array(11, '南'),
#         4 => array(13, '東'),
#         5 => array(9, '西'),
#         6 => array(),
#     ),
#     2 => array(
#         1 => array(15, '北'),
#         2 => array(10, '東'),
#         3 => array(8, '南'),
#         4 => array(7, '東'),
#         5 => array(14, '西'),
#         6 => array(),
#     ),
#     3 => array(
#         1 => array(20, '西'),
#         2 => array(20, '北'),
#         3 => array(8, '東'),
#         4 => array(19, '東'),
#         5 => array(19, '南'),
#         6 => array(),
#     ),
#     4 => array(
#         1 => array(7, '南'),
#         2 => array(7, '北'),
#         3 => array(21, '西'),
#         4 => array(10, '東'),
#         5 => array(20, '東'),
#         6 => array(),
#     ),
#     5 => array(
#         1 => array(18, '北'),
#         2 => array(20, '東'),
#         3 => array(13, '南'),
#         4 => array(4, '西'),
#         5 => array(15, '東'),
#         6 => array(),
#     ),
#     6 => array(
#         1 => array(4, '南'),
#         2 => array(14, '西'),
#         3 => array(5, '北'),
#         4 => array(3, '東'),
#         5 => array(7, '西'),
#         6 => array(),
#     ),
#     7 => array(
#         1 => array(9, '南'),
#         2 => array(2, '西'),
#         3 => array(2, '北'),
#         4 => array(16, '東'),
#         5 => array(16, '東'),
#         6 => array(),
#     ),
#     8 => array(
#         1 => array(18, '東'),
#         2 => array(14, '北'),
#         3 => array(9, '南'),
#         4 => array(12, '東'),
#         5 => array(16, '西'),
#         6 => array(),
#     ),
#     9 => array(
#         1 => array(5, '南'),
#         2 => array(5, '北'),
#         3 => array(17, '西'),
#         4 => array(16, '南'),
#         5 => array(12, '東'),
#         6 => array(),
#     ),
#     10 => array(
#         1 => array(10, '東'),
#         2 => array(14, '南'),
#         3 => array(16, '西'),
#         4 => array(2, '東'),
#         5 => array(13, '南'),
#         6 => array(),
#     ),
#     11 => array(
#         1 => array(13, '北'),
#         2 => array(18, '東'),
#         3 => array(4, '南'),
#         4 => array(12, '南'),
#         5 => array(8, '東'),
#         6 => array(),
#     ),
#     12 => array(
#         1 => array(8, '北'),
#         2 => array(1, '南'),
#         3 => array(4, '東'),
#         4 => array(20, '西'),
#         5 => array(20, '南'),
#         6 => array(),
#     ),
#     13 => array(
#         1 => array(8, '南'),
#         2 => array(8, '北'),
#         3 => array(21, '東'),
#         4 => array(21, '東'),
#         5 => array(17, '南'),
#         6 => array(),
#     ),
#     14 => array(
#         1 => array(10, '西'),
#         2 => array(1, '東'),
#         3 => array(15, '南'),
#         4 => array(17, '東'),
#         5 => array(11, '南'),
#         6 => array(),
#     ),
#     15 => array(
#         1 => array(16, '西'),
#         2 => array(17, '南'),
#         3 => array(9, '北'),
#         4 => array(5, '東'),
#         5 => array(20, '西'),
#         6 => array(),
#     ),
#     16 => array(
#         1 => array(3, '東'),
#         2 => array(15, '北'),
#         3 => array(6, '北'),
#         4 => array(16, '西'),
#         5 => array(19, '東'),
#         6 => array(),
#     ),
#     17 => array(
#         1 => array(13, '東'),
#         2 => array(13, '北'),
#         3 => array(15, '西'),
#         4 => array(2, '南'),
#         5 => array(4, '西'),
#         6 => array(),
#     ),
#     18 => array(
#         1 => array(1, '南'),
#         2 => array(2, '北'),
#         3 => array(1, '西'),
#         4 => array(20, '東'),
#         5 => array(21, '東'),
#         6 => array(),
#     ),
#     19 => array(
#         1 => array(9, '東'),
#         2 => array(9, '西'),
#         3 => array(14, '北'),
#         4 => array(14, '東'),
#         5 => array(6, '南'),
#         6 => array(),
#     ),
#     20 => array(
#         1 => array(5, '北'),
#         2 => array(15, '東'),
#         3 => array(12, '西'),
#         4 => array(11, '東'),
#         5 => array(15, '南'),
#         6 => array(),
#     ),
#     21 => array(
#         1 => array(6, '北'),
#         2 => array(2, '南'),
#         3 => array(18, '西'),
#         4 => array(9, '東'),
#         5 => array(11, '東'),
#         6 => array(),
#     ),
#     22 => array(
#         1 => array(19, '北'),
#         2 => array(6, '東'),
#         3 => array(6, '南'),
#         4 => array(6, '東'),
#         5 => array(3, '西'),
#         6 => array(),
#     ),
#     23 => array(
#         1 => array(11, '東'),
#         2 => array(13, '西'),
#         3 => array(17, '南'),
#         4 => array(13, '南'),
#         5 => array(13, '東'),
#         6 => array(),
#     ),
#     24 => array(
#         1 => array(17, '北'),
#         2 => array(1, '西'),
#         3 => array(17, '東'),
#         4 => array(3, '西'),
#         5 => array(9, '南'),
#         6 => array(),
#     ),
#     25 => array(
#         1 => array(4, '東'),
#         2 => array(20, '南'),
#         3 => array(19, '西'),
#         4 => array(20, '北'),
#         5 => array(10, '東'),
#         6 => array(),
#     ),
#     26 => array(
#         1 => array(15, '南'),
#         2 => array(18, '北'),
#         3 => array(10, '西'),
#         4 => array(11, '南'),
#         5 => array(10, '西'),
#         6 => array(),
#     ),
#     27 => array(
#         1 => array(1, '西'),
#         2 => array(12, '北'),
#         3 => array(14, '東'),
#         4 => array(1, '東'),
#         5 => array(12, '南'),
#         6 => array(),
#     ),
#     28 => array(
#         1 => array(7, '北'),
#         2 => array(3, '西'),
#         3 => array(14, '南'),
#         4 => array(15, '東'),
#         5 => array(13, '西'),
#         6 => array(),
#     ),
#     29 => array(
#         1 => array(16, '南'),
#         2 => array(16, '東'),
#         3 => array(6, '西'),
#         4 => array(21, '南'),
#         5 => array(4, '北'),
#         6 => array(),
#     ),
#     30 => array(
#         1 => array(11, '北'),
#         2 => array(12, '南'),
#         3 => array(15, '東'),
#         4 => array(15, '南'),
#         5 => array(19, '西'),
#         6 => array(),
#     ),
#     31 => array(
#         1 => array(20, '南'),
#         2 => array(4, '西'),
#         3 => array(3, '北'),
#         4 => array(17, '南'),
#         5 => array(5, '東'),
#         6 => array(),
#     ),
#     32 => array(
#         1 => array(13, '西'),
#         2 => array(19, '北'),
#         3 => array(7, '西'),
#         4 => array(19, '南'),
#         5 => array(7, '東'),
#         6 => array(),
#     ),
#     33 => array(
#         1 => array(17, '東'),
#         2 => array(16, '西'),
#         3 => array(3, '南'),
#         4 => array(4, '北'),
#         5 => array(17, '東'),
#         6 => array(),
#     ),
#     34 => array(
#         1 => array(7, '東'),
#         2 => array(9, '南'),
#         3 => array(11, '北'),
#         4 => array(17, '西'),
#         5 => array(1, '南'),
#         6 => array(),
#     ),
#     35 => array(
#         1 => array(3, '西'),
#         2 => array(3, '南'),
#         3 => array(5, '南'),
#         4 => array(10, '北'),
#         5 => array(10, '北'),
#         6 => array(),
#     ),
#     36 => array(
#         1 => array(10, '北'),
#         2 => array(7, '南'),
#         3 => array(3, '西'),
#         4 => array(7, '南'),
#         5 => array(12, '西'),
#         6 => array(),
#     ),
#     37 => array(
#         1 => array(12, '東'),
#         2 => array(8, '南'),
#         3 => array(15, '北'),
#         4 => array(1, '南'),
#         5 => array(1, '西'),
#         6 => array(),
#     ),
#     38 => array(
#         1 => array(10, '南'),
#         2 => array(16, '北'),
#         3 => array(13, '西'),
#         4 => array(15, '西'),
#         5 => array(9, '東'),
#         6 => array(),
#     ),
#     39 => array(
#         1 => array(5, '東'),
#         2 => array(13, '南'),
#         3 => array(11, '西'),
#         4 => array(8, '東'),
#         5 => array(5, '北'),
#         6 => array(),
#     ),
#     40 => array(
#         1 => array(21, '南'),
#         2 => array(21, '北'),
#         3 => array(2, '東'),
#         4 => array(14, '南'),
#         5 => array(5, '西'),
#         6 => array(),
#     ),
#     41 => array(
#         1 => array(9, '西'),
#         2 => array(14, '東'),
#         3 => array(6, '東'),
#         4 => array(9, '南'),
#         5 => array(1, '北'),
#         6 => array(),
#     ),
#     42 => array(
#         1 => array(2, '東'),
#         2 => array(16, '南'),
#         3 => array(20, '西'),
#         4 => array(2, '西'),
#         5 => array(8, '南'),
#         6 => array(),
#     ),
#     43 => array(
#         1 => array(6, '南'),
#         2 => array(19, '西'),
#         3 => array(11, '東'),
#         4 => array(14, '西'),
#         5 => array(21, '北'),
#         6 => array(),
#     ),
#     44 => array(
#         1 => array(8, '西'),
#         2 => array(11, '東'),
#         3 => array(17, '北'),
#         4 => array(8, '南'),
#         5 => array(6, '西'),
#         6 => array(),
#     ),
#     45 => array(
#         1 => array(7, '西'),
#         2 => array(10, '北'),
#         3 => array(7, '南'),
#         4 => array(5, '南'),
#         5 => array(4, '東'),
#         6 => array(),
#     ),
#     46 => array(
#         1 => array(20, '東'),
#         2 => array(6, '南'),
#         3 => array(9, '西'),
#         4 => array(8, '北'),
#         5 => array(14, '東'),
#         6 => array(),
#     ),
#     47 => array(
#         1 => array(16, '北'),
#         2 => array(11, '西'),
#         3 => array(4, '西'),
#         4 => array(4, '東'),
#         5 => array(13, '北'),
#         6 => array(),
#     ),
#     48 => array(
#         1 => array(14, '北'),
#         2 => array(21, '南'),
#         3 => array(19, '東'),
#         4 => array(15, '北'),
#         5 => array(18, '東'),
#         6 => array(),
#     ),
#     49 => array(
#         1 => array(6, '西'),
#         2 => array(10, '南'),
#         3 => array(10, '東'),
#         4 => array(18, '東'),
#         5 => array(3, '北'),
#         6 => array(),
#     ),
#     50 => array(
#         1 => array(5, '西'),
#         2 => array(1, '北'),
#         3 => array(3, '東'),
#         4 => array(2, '北'),
#         5 => array(14, '南'),
#         6 => array(),
#     ),
#     51 => array(
#         1 => array(16, '東'),
#         2 => array(18, '西'),
#         3 => array(13, '北'),
#         4 => array(1, '西'),
#         5 => array(18, '南'),
#         6 => array(),
#     ),
#     52 => array(
#         1 => array(4, '北'),
#         2 => array(21, '東'),
#         3 => array(1, '南'),
#         4 => array(5, '西'),
#         5 => array(3, '東'),
#         6 => array(),
#     ),
#     53 => array(
#         1 => array(21, '東'),
#         2 => array(20, '西'),
#         3 => array(20, '南'),
#         4 => array(17, '北'),
#         5 => array(6, '北'),
#         6 => array(),
#     ),
#     54 => array(
#         1 => array(2, '南'),
#         2 => array(11, '北'),
#         3 => array(18, '東'),
#         4 => array(3, '北'),
#         5 => array(17, '西'),
#         6 => array(),
#     ),
#     55 => array(
#         1 => array(2, '北'),
#         2 => array(2, '東'),
#         3 => array(7, '東'),
#         4 => array(8, '西'),
#         5 => array(3, '南'),
#         6 => array(),
#     ),
#     56 => array(
#         1 => array(20, '北'),
#         2 => array(15, '西'),
#         3 => array(19, '南'),
#         4 => array(18, '南'),
#         5 => array(6, '東'),
#         6 => array(),
#     ),
#     57 => array(
#         1 => array(12, '南'),
#         2 => array(21, '西'),
#         3 => array(12, '東'),
#         4 => array(12, '西'),
#         5 => array(20, '北'),
#         6 => array(),
#     ),
#     58 => array(
#         1 => array(18, '南'),
#         2 => array(7, '西'),
#         3 => array(16, '東'),
#         4 => array(14, '北'),
#         5 => array(11, '西'),
#         6 => array(),
#     ),
#     59 => array(
#         1 => array(15, '西'),
#         2 => array(19, '南'),
#         3 => array(19, '北'),
#         4 => array(21, '西'),
#         5 => array(19, '北'),
#         6 => array(),
#     ),
#     60 => array(
#         1 => array(6, '東'),
#         2 => array(17, '西'),
#         3 => array(5, '西'),
#         4 => array(20, '南'),
#         5 => array(9, '北'),
#         6 => array(),
#     ),
#     61 => array(
#         1 => array(14, '南'),
#         2 => array(3, '東'),
#         3 => array(18, '北'),
#         4 => array(18, '西'),
#         5 => array(1, '東'),
#         6 => array(),
#     ),
#     62 => array(
#         1 => array(21, '北'),
#         2 => array(8, '西'),
#         3 => array(9, '東'),
#         4 => array(9, '西'),
#         5 => array(21, '南'),
#         6 => array(),
#     ),
#     63 => array(
#         1 => array(13, '南'),
#         2 => array(8, '東'),
#         3 => array(20, '北'),
#         4 => array(7, '西'),
#         5 => array(16, '北'),
#         6 => array(),
#     ),
#     64 => array(
#         1 => array(17, '南'),
#         2 => array(17, '東'),
#         3 => array(8, '北'),
#         4 => array(18, '北'),
#         5 => array(18, '西'),
#         6 => array(),
#     ),
#     65 => array(
#         1 => array(1, '東'),
#         2 => array(15, '南'),
#         3 => array(21, '北'),
#         4 => array(6, '南'),
#         5 => array(8, '北'),
#         6 => array(),
#     ),
#     66 => array(
#         1 => array(2, '西'),
#         2 => array(7, '東'),
#         3 => array(1, '北'),
#         4 => array(1, '北'),
#         5 => array(7, '南'),
#         6 => array(),
#     ),
#     67 => array(
#         1 => array(8, '東'),
#         2 => array(18, '南'),
#         3 => array(2, '西'),
#         4 => array(9, '北'),
#         5 => array(7, '北'),
#         6 => array(),
#     ),
#     68 => array(
#         1 => array(9, '北'),
#         2 => array(12, '西'),
#         3 => array(7, '北'),
#         4 => array(3, '南'),
#         5 => array(2, '東'),
#         6 => array(),
#     ),
#     69 => array(
#         1 => array(4, '西'),
#         2 => array(19, '東'),
#         3 => array(2, '南'),
#         4 => array(12, '北'),
#         5 => array(17, '北'),
#         6 => array(),
#     ),
#     70 => array(
#         1 => array(11, '西'),
#         2 => array(17, '北'),
#         3 => array(18, '南'),
#         4 => array(21, '北'),
#         5 => array(8, '西'),
#         6 => array(),
#     ),
#     71 => array(
#         1 => array(17, '西'),
#         2 => array(12, '東'),
#         3 => array(12, '北'),
#         4 => array(19, '西'),
#         5 => array(10, '南'),
#         6 => array(),
#     ),
#     72 => array(
#         1 => array(14, '西'),
#         2 => array(9, '北'),
#         3 => array(1, '東'),
#         4 => array(11, '北'),
#         5 => array(5, '南'),
#         6 => array(),
#     ),
#     73 => array(
#         1 => array(14, '東'),
#         2 => array(11, '南'),
#         3 => array(16, '北'),
#         4 => array(10, '南'),
#         5 => array(2, '北'),
#         6 => array(),
#     ),
#     74 => array(
#         1 => array(19, '南'),
#         2 => array(10, '西'),
#         3 => array(20, '東'),
#         4 => array(13, '西'),
#         5 => array(12, '北'),
#         6 => array(),
#     ),
#     75 => array(
#         1 => array(12, '西'),
#         2 => array(4, '東'),
#         3 => array(16, '南'),
#         4 => array(6, '西'),
#         5 => array(14, '北'),
#         6 => array(),
#     ),
#     76 => array(
#         1 => array(11, '南'),
#         2 => array(9, '東'),
#         3 => array(8, '西'),
#         4 => array(16, '北'),
#         5 => array(15, '北'),
#         6 => array(),
#     ),
#     77 => array(
#         1 => array(3, '南'),
#         2 => array(13, '東'),
#         3 => array(10, '北'),
#         4 => array(19, '北'),
#         5 => array(15, '西'),
#         6 => array(),
#     ),
#     78 => array(
#         1 => array(1, '北'),
#         2 => array(5, '西'),
#         3 => array(5, '東'),
#         4 => array(4, '南'),
#         5 => array(4, '南'),
#         6 => array(),
#     ),
#     79 => array(
#         1 => array(21, '西'),
#         2 => array(5, '東'),
#         3 => array(12, '南'),
#         4 => array(6, '北'),
#         5 => array(18, '北'),
#         6 => array(),
#     ),
#     80 => array(
#         1 => array(3, '北'),
#         2 => array(5, '南'),
#         3 => array(13, '東'),
#         4 => array(13, '北'),
#         5 => array(21, '西'),
#         6 => array(),
#     ),
#     81 => array(
#         1 => array(19, '東'),
#         2 => array(4, '北'),
#         3 => array(4, '北'),
#         4 => array(11, '西'),
#         5 => array(16, '南'),
#         6 => array(),
#     ),
#     82 => array(
#         1 => array(12, '北'),
#         2 => array(6, '西'),
#         3 => array(10, '南'),
#         4 => array(7, '北'),
#         5 => array(2, '南'),
#         6 => array(),
#     ),
#     83 => array(
#         1 => array(15, '東'),
#         2 => array(4, '南'),
#         3 => array(14, '西'),
#         4 => array(10, '西'),
#         5 => array(11, '北'),
#         6 => array(),
#     ),
#     84 => array(
#         1 => array(19, '西'),
#         2 => array(3, '北'),
#         3 => array(21, '南'),
#         4 => array(5, '北'),
#         5 => array(2, '西'),
#         6 => array(),
#     ),
# );
